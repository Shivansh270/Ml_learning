# %%
import pandas as pd

# %%
df = pd.read_csv("Student-Performance-csv_T4qDx.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isnull()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
#checking the count of the null values
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df["Extracurricular Activities"]
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3       Yes
# 4        No
#        ...
# 9995    Yes
# 9996    Yes
# 9997    Yes
# 9998    Yes
# 9999     No
# Name: Extracurricular Activities, Length: 10000, dtype: object

# %%
le = LabelEncoder()
df["Extracurricular Activities"] = le.fit_transform(df["Extracurricular Activities"])

# %%
df["Extracurricular Activities"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    0
# Name: Extracurricular Activities, Length: 10000, dtype: int64

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %% [markdown]
# Making the equation of the line dependent(x) and independent variable(y),,,
#                      y = mx+c

# %%
x = df[["Hours Studied"	,"Previous Scores","Extracurricular Activities",	"Sleep Hours"	,"Sample Question Papers Practiced"]]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
y = df["Performance Index"]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %% [markdown]
# PERFORM TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 4003              3               57                           1            7
# 8100              7               41                           0            7
# 3399              3               73                           1            6
# 7437              1               49                           0            5
# 1413              4               66                           0            6
# ...             ...              ...                         ...          ...
# 9892              8               75                           1            8
# 4420              8               87                           1            4
# 7756              8               98                           0            6
# 1883              4               86                           1            8
# 1966              4               49                           0            4
#
# ...

# %%
x_test
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 7351              4               54                           0            4
# 9707              4               52                           0            4
# 1266              2               63                           0            7
# 6662              9               93                           1            9
# 6825              9               42                           0            5
# ...             ...              ...                         ...          ...
# 8486              9               53                           0            9
# 8815              4               88                           1            7
# 2950              7               97                           1            9
# 1721              5               54                           1            8
# 6804              2               99                           0            6
#
# ...

# %%
y_test
# Out:
# 7351    37.0
# 9707    32.0
# 1266    42.0
# 6662    93.0
# 6825    37.0
#         ...
# 8486    51.0
# 8815    73.0
# 2950    91.0
# 1721    41.0
# 6804    73.0
# Name: Performance Index, Length: 2000, dtype: float64

# %% [markdown]
# scaling values and buildong the model

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error ,median_absolute_error, r2_score
import pickle

# %%
model = LinearRegression()
model.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
#Predicting the values from the trained model for the complete test set
y_pred = model.predict(x_test_scaled)

# %%
x_test_scaled
# Out:
# array([[ 1.59245199,  0.28845368, -0.97530483, -0.93176074,  0.07958954],
#        [-0.35502507,  1.10403512,  1.02532046, -0.93176074, -1.65061785],
#        [ 1.20295658,  0.28845368, -0.97530483, -0.93176074,  0.07958954],
#        ...,
#        [ 0.42396576, -1.63398829, -0.97530483,  0.86123619,  0.07958954],
#        [-1.5235113 , -0.52712776, -0.97530483, -0.93176074, -0.95853489],
#        [-0.35502507, -1.69224411, -0.97530483, -0.93176074, -1.30457637]])

# %%
model.predict([[1.59245199,  0.28845368, -0.97530483, -0.93176074,  0.07958954]])
# Out:
# array([71.22639853])

# %%
mean_squared_error( y_test ,y_pred)
# Out:
# 4.570331587294549

# %%
r2_score(y_test ,y_pred)
# Out:
# 0.9874533941484566

# %%
model
# Out:
# LinearRegression()

# %%
import pickle

with open('model.pkl', 'wb') as file:
    pickle.dump((model, le, scaler), file)
