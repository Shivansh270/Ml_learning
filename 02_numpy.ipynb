# %%
#numerical python-> numerical operations on data (array and matrix)
import numpy as np

# %%
np.array([2,4,6,4,5])
# Out:
# array([2, 4, 6, 4, 5])

# %%
a1 = np.array([[3,5,7,7], [3,15,8,2]])

# %%
a1.shape
# Out:
# (2, 4)

# %%
#elements in array
a1.size
# Out:
# 8

# %%
#random int value or array
#random array of elements bw 1 to 10 and of soze 3X4
np.random.randint(1,10,(3,4))
# Out:
# array([[9, 8, 1, 8],
#        [5, 1, 3, 7],
#        [3, 4, 1, 7]])

# %%
#2 represent the total array to be formed and a 3d array
# 3 bracket means 3d data
#last represent number of values in roq
np.random.randint(1,10,(2,4,10))
# Out:
# array([[[3, 4, 1, 7, 3, 7, 8, 9, 3, 8],
#         [9, 9, 6, 5, 7, 7, 7, 5, 4, 1],
#         [1, 1, 3, 6, 1, 9, 1, 9, 1, 3],
#         [9, 4, 3, 2, 3, 3, 9, 2, 3, 9]],
#
#        [[1, 2, 1, 1, 8, 1, 2, 4, 6, 3],
#         [7, 3, 9, 8, 3, 5, 5, 2, 4, 7],
#         [3, 9, 5, 1, 6, 9, 3, 8, 8, 4],
#         [7, 6, 7, 3, 3, 8, 2, 6, 1, 5]]])

# %%
from PIL import Image

img = Image.open("Photograph.jpg")

# %%
np.array(img)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 76,  83, 109],
#         [ 98, 105, 131],
#         [ 98, 105, 131],
#         ...,
#         [ 79,  81, 104],
#         [ 79,  81, 104],
#         [ 79,  81, 104]],
#
#        [[ 85,  95, 120],
#         [ 89,  99, 124],
#         [ 91, 101, 126],
#         ...,
#         [ 75,  77, 100],
#         [ 76,  78, 101],
#         [ 75,  77, 100]],
#
#        [[ 83,  93, 118],
#         [ 87,  97, 122],
#         [ 89,  99, 124],
# ...

# %%
img.size
# Out:
# (861, 1026)

# %%
shiv_img = np.array(img)

# %%
#dimension of array
shiv_img.ndim
# Out:
# 3

# %%
#Numner of elements in array
shiv_img.size
# Out:
# 2650158

# %%
a1 = np.array([[1,2], [3,5]])
a2 = np.array([[2,3], [4,2]])

# %%
a1*a2
# Out:
# array([[ 2,  6],
#        [12, 10]])

# %%
#matrix multiplicatiom
a1@a2
#or
np.dot(a1,a2)
# Out:
# array([[10,  7],
#        [26, 19]])

# %% [markdown]
# real usecase of matrix multiplication

# %%
shiv_img.shape
# Out:
# (1026, 861, 3)

# %%
random_arr = np.random.randint(1,3 , (1026, 861, 3))

# %%
random_arr.shape
# Out:
# (1026, 861, 3)

# %%
after_multiply = shiv_img * random_arr

# %%
after_multiply
# Out:
# array([[[255, 765, 765],
#         [510, 255, 255],
#         [255, 510, 255],
#         ...,
#         [255, 765, 765],
#         [255, 255, 510],
#         [510, 255, 255]],
#
#        [[510, 765, 255],
#         [255, 765, 510],
#         [255, 765, 765],
#         ...,
#         [765, 255, 510],
#         [255, 255, 510],
#         [765, 510, 765]],
#
#        [[765, 255, 510],
#         [765, 510, 255],
#         [765, 510, 255],
#         ...,
#         [765, 765, 255],
#         [510, 510, 255],
#         [255, 510, 255]],
#
#        ...,
#
#        [[228,  83, 218],
#         [196, 210, 262],
#         [196, 210, 131],
#         ...,
#         [158, 162, 208],
#         [237, 243, 104],
#         [158, 243, 104]],
#
#        [[ 85, 285, 120],
#         [ 89, 297, 124],
#         [182, 202, 126],
#         ...,
#         [150,  77, 300],
#         [228,  78, 303],
#         [150,  77, 300]],
#
#        [[166, 186, 354],
#         [261, 291, 366],
#         [ 89, 198, 248],
# ...

# %%
#normalize array
after_normal = (after_multiply*255).astype(np.uint8)

# %%
Image.fromarray(after_normal)
# Out:
# <PIL.Image.Image image mode=RGB size=861x1026>

# %%
a1 = np.array([2,-3,4])

# %%
a1
# Out:
# array([ 2, -3,  4])
